# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Yash\\OneDrive\\Desktop\\ML_Project\\notebooks'

# %%
import joblib
import pandas as pd

model = joblib.load("../models/best_model.pkl")

data = pd.read_csv("../data/sample_input.csv")


predictions = model.predict(data)


data["Predicted_Item_Outlet_Sales"] = predictions
data.to_csv("../data/predictions_output.csv", index=False)

print("Day 15 completed successfully")
# Out:
# Day 15 completed successfully
